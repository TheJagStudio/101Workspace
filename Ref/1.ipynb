# %%
import concurrent.futures
import requests
import json
import os
import random

with open("productsId.txt", "r") as file:
    products = [line.strip() for line in file.readlines()]
random.shuffle(products)
def update_product_inventory(id):
    file_path = f"./data/{id}.json"
    if os.path.exists(file_path):
        print(f"File already exists for product ID: {id}, skipping.")
        return
    
    headers = {
        "Accept": "application/json, text/plain",
        "Accept-Language": "en-US,en;q=0.9,gu;q=0.8,ru;q=0.7,hi;q=0.6",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJkaGF2YWwucEAxMDFkaXN0cmlidXRvcnNnYS5jb20iLCJ1c2VyVHlwZSI6IkVtcGxveWVlIiwidG9rZW5UeXBlIjoiYWNjZXNzIiwic3RvcmVJZCI6MSwiZXhwIjoxNzQ4NzMxMTM0LCJ1c2VySWQiOjIwLCJpYXQiOjE3NDg2MTExMzQsInJlc2V0UGFzc3dvcmRSZXF1aXJlZCI6ZmFsc2V9.d-1dV7PyqE_ZrJogjcl-THU7LaICq6zMnvTcMehZOkk" ,
        "Cache-Control": "no-cache",
        "Connection": "keep-alive",
        "Pragma": "no-cache",
        "Referer": "https://erp.101distributorsga.com/",
        "Sec-Fetch-Dest": "empty",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "same-origin",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36",
        "sec-ch-ua": '"Chromium";v="136", "Google Chrome";v="136", "Not.A/Brand";v="99"',
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": '"Windows"',
    }
    
    response = requests.get(f"https://erp.101distributorsga.com/api/inventory/history/{id}?storeIds=1,2", headers=headers)
    data = response.json()["result"]
    with open(file_path, "w") as f:
        f.write(json.dumps(data, indent=4))
    print(f"Downloaded inventory for product ID: {id}")

# Use ThreadPoolExecutor for concurrent requests
batch_size = 10
with concurrent.futures.ThreadPoolExecutor(max_workers=batch_size) as executor:
    for i in range(0, len(products), batch_size):
        batch = products[i:i + batch_size]
        futures = [executor.submit(update_product_inventory, product) for product in batch]
        concurrent.futures.wait(futures)

# %%
import concurrent.futures
import requests
import json
import os
import random

with open("productsId.txt", "r") as file:
    products = [line.strip() for line in file.readlines()]
random.shuffle(products)
def fetch_product_history(id):
    file_path = f"./data/{id}.json"
    if os.path.exists(file_path):
        print(f"File already exists for product ID: {id}, skipping.")
        return
    pages = 1
    totalData = []
    i = 0
    while i < pages :
        headers = {
            'Accept': 'application/json, text/plain',
            'Accept-Language': 'en-US,en;q=0.9,gu;q=0.8,ru;q=0.7,hi;q=0.6',
            'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJkaGF2YWwucEAxMDFkaXN0cmlidXRvcnNnYS5jb20iLCJ1c2VyVHlwZSI6IkVtcGxveWVlIiwidG9rZW5UeXBlIjoiYWNjZXNzIiwic3RvcmVJZCI6MSwiZXhwIjoxNzQ4NzMxMTM0LCJ1c2VySWQiOjIwLCJpYXQiOjE3NDg2MTExMzQsInJlc2V0UGFzc3dvcmRSZXF1aXJlZCI6ZmFsc2V9.d-1dV7PyqE_ZrJogjcl-THU7LaICq6zMnvTcMehZOkk',
            'Cache-Control': 'no-cache',
            'Connection': 'keep-alive',
            'Pragma': 'no-cache',
            'Referer': 'https://erp.101distributorsga.com/',
            'Sec-Fetch-Dest': 'empty',
            'Sec-Fetch-Mode': 'cors',
            'Sec-Fetch-Site': 'same-origin',
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36',
            'sec-ch-ua': '"Chromium";v="136", "Google Chrome";v="136", "Not.A/Brand";v="99"',
            'sec-ch-ua-mobile': '?0',
            'sec-ch-ua-platform': '"Windows"',
        }

        response = requests.get(
            f"https://erp.101distributorsga.com/api/report/sales/byProductSummary/product/{id}?storeIds=1,2&status=Pending+Payment,Partially+Paid,Paid,Completed&shippingStatusIds=664,665&startDate=2019-01-01+05:00:00&endDate=2025-05-31+03:59:59&page="+str(i)+"&size=500",
            headers=headers,
        )
        
        pages = response.json()["result"]["salesByProductList"]["totalPages"]
        totalData.extend(response.json()["result"]["salesByProductList"]["content"])
        print(f"Downloading history for product ID: {id} at page: {i+1}/{pages}")
        if pages <= 1:
            break
        i += 1
    with open(file_path, "w") as f:
        f.write(json.dumps(totalData, indent=4))

# Use ThreadPoolExecutor for concurrent requests
batch_size = 10
with concurrent.futures.ThreadPoolExecutor(max_workers=batch_size) as executor:
    for i in range(0, len(products), batch_size):
        batch = products[i:i + batch_size]
        futures = [executor.submit(fetch_product_history, product) for product in batch]
        concurrent.futures.wait(futures)
# Out:
# File already exists for product ID: 22200, skipping.
# File already exists for product ID: 34124, skipping.
# File already exists for product ID: 1176, skipping.
# ...
# File already exists for product ID: 8971, skipping.
# ...
# File already exists for product ID: 10548, skipping.
# File already exists for product ID: 54186, skipping.
# ...
#
# ...
# File already exists for product ID: 34098, skipping.
# File already exists for product ID: 12560, skipping.
# File already exists for product ID: 45695, skipping.
# File already exists for product ID: 9234, skipping.
# ...
# File already exists for product ID: 38962, skipping.
# ...
# File already exists for product ID: 57846, skipping.
# File already exists for product ID: 50032, skipping.
# File already exists for product ID: 9851, skipping.
# ...
# File already exists for product ID: 18837, skipping.
# ...
# File already exists for product ID: 34410, skipping.
# File already exists for product ID: 56932, skipping.
# ...
# File already exists for product ID: 21793, skipping.
# ...
